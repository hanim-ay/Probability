# %% [markdown]
# <a href="https://colab.research.google.com/github/hanim-ay/Probability/blob/main/Bayes_Teoremi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **BAYES TEOREMİ**
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
B1=0.35
B2=0.25
B3=0.40
A_B1=0.01
A_B2=0.03
A_B3= 0.02
Bayes_Teoremi=((B1*A_B1)/((B1*A_B1)+(B2*A_B2)+(B3*A_B3)))
print(Bayes_Teoremi)
# Out:
# 0.18421052631578946
