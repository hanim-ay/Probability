# %% [markdown]
# <a href="https://colab.research.google.com/github/hanim-ay/Probability/blob/main/Kosullu_Olasilik.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **KOŞULLU OLASILIK**
#
# E örnek uzayının iki olayı A ve B olsun. B olayının gerçekleştiği bilindiğine göre, A olayının gerçekleşmesi olasılığına A olayının B şartlı olasılığı (A olayının B ye bağlı koşullu olasılığı) denir. P(A/B) şeklinde gösterilir.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
E= {'1','2','3','4','5','6'}
A= {'3','4','5','6'}
B= {'2','4','6'}

A_kesisim_B= A.intersection(B)

result=len(A_kesisim_B)/len(A)

print(result)
# Out:
# 0.5
